# %%
# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv('data/adrf-000023.csv')
fig = df.plot('X', 'Y')

# %%
fig.get_figure().savefig('graph.png')

# %%
import IPython

# %%
IPython.display.publish_display_data({
    "application/ld+json": {
        "@id": "file:///graph.png",
        "http://www.w3.org/2000/01/rdf-schema#seeAlso": {
            "@id": "https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary#dataset-2b4bcbd0e00931b60b49"
        }
    }
})
